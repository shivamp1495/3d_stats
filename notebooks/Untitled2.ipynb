# %%
# %reset
import sys, os
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import scipy.integrate as integrate
import random
import healpy as hp
from astropy.io import fits
from astropy.coordinates import SkyCoord
from numpy.random import rand
import pickle as pk
import matplotlib.cm as cm
import scipy.interpolate as interpolate
import pdb
import time
import multiprocessing as mp
sys.path.insert(0,'/global/project/projectdirs/des/shivamp/cosmosis/y3kp-bias-model/3d_stats/process_measure_data/')
import correlate_gg_gm_3d_class as corr_class
import argparse
import subprocess
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y

# %%
# !python '/global/project/projectdirs/des/shivamp/cosmosis/y3kp-bias-model/3d_stats/process_measure_data/correlate_gg_gm_3d_funcs_mice_halos.py' --bin 2 --lm_min 12.0 --lm_max 12.5
# Out:
# nthreads are  64
# loading g
# loading m
# loading rg
# loading rm
# number of galaxies :  1465276
# number of matter particles :  2212928
# number of galaxies randoms:  14652952
# number of matter randoms:  22128532
# setting up the class
# number of galaxies  1465276
# number of galaxy randoms  14652952
# number of matter  2212928
# number of matter randoms  22128532
# correlating gg
# correlating g g
# time for correlating g g  4.511070966720581
# correlating g rg
# time for correlating g rg  43.2964186668396
# correlating rg rg
# time for correlating rg rg  172.18596291542053
# r_gg [ 0.88914847  1.0944975   1.34740766  1.65914949  2.04150216  2.51125817
#   3.089141    3.8018242   4.67707637  5.75434083  7.07870058  8.70739178
#  10.71114782 13.17446829 16.20455287 19.93076665 24.51322223 30.14687249
#  37.07415015 45.59262287]
# xi_gg [1.00616396e+01 7.70445557e+00 5.63081722e+00 4.10087214e+00
#  2.95742286e+00 2.19969553e+00 1.61982764e+00 1.20957404e+00
# ...

# %%
# !python '/global/project/projectdirs/des/shivamp/cosmosis/y3kp-bias-model/3d_stats/process_measure_data/correlate_gg_gm_3d_funcs_mice_halos.py' --bin 5 --lm_min 12.0 --lm_max 12.5 --do_gg 0 --do_gm 1 --do_mm 1
# Out:
# nthreads are  64
# loading g
# loading m
# loading rg
# loading rm
# number of galaxies :  4086252
# number of matter particles :  6689040
# number of galaxies randoms:  40593507
# number of matter randoms:  66440448
# setting up the class
# number of galaxies  4086252
# number of galaxy randoms  40593507
# number of matter  6689040
# number of matter randoms  66440448
# correlating gm
# correlating g m
# time for correlating g m  34.5825457572937
# correlating g rm
# time for correlating g rm  468.87577986717224
# correlating m rg
# time for correlating m rg  197.69376349449158
# correlating rm rg
# time for correlating rm rg  485.32788372039795
# r_gm [ 0.89637964  1.10318524  1.36470928  1.65056682  2.04251284  2.51440911
#   3.09241426  3.80385187  4.67944223  5.75613574  7.08054435  8.70921372
#  10.71237456 13.17612144 16.20612725 19.93192816 24.51409193 30.14882703
#  37.07757858 45.59710443]
# xi_gm [2.8745966  2.91481816 3.76901179 3.87966392 2.08216028 1.59118308
# ...

# %%
# !python '/global/project/projectdirs/des/shivamp/cosmosis/y3kp-bias-model/3d_stats/process_measure_data/correlate_gg_gm_3d_funcs_mice_halos.py' --bin 1 --lm_min 13.5 --lm_max 14.0
# Out:
# nthreads are  64
# loading g
# loading m
# loading rg
# loading rm
# number of galaxies :  16649
# number of matter particles :  915752
# number of galaxies randoms:  166459
# number of matter randoms:  9157245
# setting up the class
# number of galaxies  16649
# number of galaxy randoms  166459
# number of matter  915752
# number of matter randoms  9157245
# correlating gg
# correlating g g
# time for correlating g g  0.05157303810119629
# correlating g rg
# time for correlating g rg  0.1897425651550293
# correlating rg rg
# time for correlating rg rg  0.29491305351257324
# r_gg [ 0.88712943  1.09089007  1.34145154  1.69307028  2.06599135  2.53087365
#   3.09699939  3.78719027  4.65521538  5.73283407  7.057916    8.67997998
#  10.68297691 13.14618494 16.17107574 19.87983114 24.48278155 30.10008196
#  37.03964248 45.57347572]
# xi_gg [-3.17584081e-01 -8.41762268e-01 -9.01285264e-01 -5.50144254e-03
#   6.33156628e+00  1.02248050e+01  9.53427722e+00  7.52047218e+00
# ...

# %%
# !python '/global/project/projectdirs/des/shivamp/cosmosis/y3kp-bias-model/3d_stats/process_measure_data/correlate_gg_gm_3d_funcs_mice_halos.py' --bin 4 --lm_min 13.5 --lm_max 14.0
# Out:
# nthreads are  64
# loading g
# loading m
# loading rg
# loading rm
# number of galaxies :  59788
# number of matter particles :  5256321
# number of galaxies randoms:  598062
# number of matter randoms:  52562421
# setting up the class
# number of galaxies  59788
# number of galaxy randoms  598062
# number of matter  5256321
# number of matter randoms  52562421
# correlating gg
# correlating g g
# time for correlating g g  0.32766127586364746
# correlating g rg
# time for correlating g rg  2.0830626487731934
# correlating rg rg
# time for correlating rg rg  1.319953203201294
# r_gg [ 0.88712943  1.09089007  1.34145154  1.70876933  2.07964849  2.52829578
#   3.09478852  3.78529486  4.65120945  5.73067708  7.05216614  8.6806677
#  10.67972043 13.14178763 16.1570368  19.88310731 24.46426246 30.1071813
#  37.02884417 45.54116587]
# xi_gg [-1.08208158 -1.13995471 -1.12830725  0.16926774  7.67140194 13.98224633
#  13.83537734 10.44698858  6.81373229  4.81691695  3.38528793  2.30268269
# ...

# %%
# !python '/global/project/projectdirs/des/shivamp/cosmosis/y3kp-bias-model/3d_stats/process_measure_data/correlate_gg_gm_3d_funcs_mice_halos.py' --bin 3 --lm_min 14.0 --lm_max 14.5
# Out:
# nthreads are  64
# loading g
# loading m
# loading rg
# loading rm
# number of galaxies :  7432
# number of matter particles :  3668927
# number of galaxies randoms:  74359
# number of matter randoms:  36688621
# setting up the class
# number of galaxies  7432
# number of galaxy randoms  74359
# number of matter  3668927
# number of matter randoms  36688621
# correlating gg
# correlating g g
# time for correlating g g  0.039273738861083984
# correlating g rg
# time for correlating g rg  0.19972586631774902
# correlating rg rg
# time for correlating rg rg  0.060100555419921875
# r_gg [ 0.88712943  1.09089007  1.34145154  1.64956332  2.02844385  2.69819597
#   3.10845312  3.83564125  4.64147584  5.7585854   7.0626174   8.66589555
#  10.5798817  13.12987736 16.10681224 19.82845208 24.42690777 30.04131241
#  36.99624604 45.48589856]
# xi_gg [-5.67016505  1.         -1.00104952 -0.11169418 -2.01745562  0.90099759
#   7.89344944 20.13990414 14.353192   12.05485019  6.85172103  4.99809127
# ...

# %%
# !python '/global/project/projectdirs/des/shivamp/cosmosis/y3kp-bias-model/3d_stats/process_measure_data/correlate_gg_gm_3d_funcs_mice_halos.py' --bin 5 --lm_min 14.0 --lm_max 14.5
# Out:
# nthreads are  64
# loading g
# loading m
# loading rg
# loading rm
# number of galaxies :  6711
# number of matter particles :  6689040
# number of galaxies randoms:  66864
# number of matter randoms:  66440448
# setting up the class
# number of galaxies  6711
# number of galaxy randoms  66864
# number of matter  6689040
# number of matter randoms  66440448
# correlating gg
# correlating g g
# time for correlating g g  0.11606478691101074
# correlating g rg
# time for correlating g rg  0.23204445838928223
# correlating rg rg
# time for correlating rg rg  0.05835080146789551
# r_gg [ 0.88712943  1.09089007  1.34145154  1.64956332  2.02844385  2.62329671
#   3.14148531  3.86815875  4.69120885  5.71988432  7.04517883  8.63869231
#  10.62630409 13.10438824 16.10124906 19.77113018 24.48282557 30.06023976
#  36.98188161 45.54139391]
# xi_gg [ 1.          1.         -2.32111459 -1.29923318 -0.99266875  3.22176212
#  14.4098363  22.43202205 21.28159907 16.65809368 10.73708893  8.19754793
# ...

# %%
# !python '/global/project/projectdirs/des/shivamp/cosmosis/y3kp-bias-model/3d_stats/process_measure_data/data_cov_reformat_mice_halos.py'
# Out:
# 5
# (200, 200)
# 5
# (200, 200)
# 5
# (200, 200)
# /global/project/projectdirs/des/shivamp/cosmosis/y3kp-bias-model/3d_stats/process_measure_data/data_cov_reformat_mice_halos.py:324: RuntimeWarning: invalid value encountered in sqrt
#   ax.errorbar(r_ratio_all[j]*(1.01)**j, np.sqrt(xi_gg_mm_true[j * nrad:(j + 1) * nrad]), np.sqrt(sig_ratio_diag[j * nrad:(j + 1) * nrad]),
# 5
# (200, 200)
# 5
# (200, 200)
# /global/project/projectdirs/des/shivamp/cosmosis/y3kp-bias-model/3d_stats/process_measure_data/data_cov_reformat_mice_halos.py:238: RuntimeWarning: invalid value encountered in double_scalars
#   corr[ii, jj] = cov[ii, jj] / np.sqrt(cov[ii, ii] * cov[jj, jj])
