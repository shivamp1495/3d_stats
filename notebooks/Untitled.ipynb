# %%
# %reset
import sys, os
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import scipy.integrate as integrate
import random
# import healpy as hp
# from astropy.io import fits
# from astropy.coordinates import SkyCoord
# from numpy.random import rand
# import pickle as pk
# import matplotlib.cm as cm
# import scipy.interpolate as interpolate
# import pdb
# import time
# import multiprocessing as mp
# sys.path.insert(0,'/global/project/projectdirs/des/shivamp/cosmosis/y3kp-bias-model/3d_stats/process_measure_data/')
# import correlate_gg_gm_3d_class as corr_class
# import argparse
# import subprocess
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y

# %%
# !python '/global/project/projectdirs/des/shivamp/cosmosis/y3kp-bias-model/3d_stats/process_measure_data/correlate_gg_gm_3d_funcs_mice.py' --bin 3 --do_gg 1 --do_gm 1 --do_mm 1 --ds_m_inp 1.67 --njk_radec 300
# Out:
# 4.0.9
# nthreads are  64
# loading g
# loading m
# loading rg
# loading rm
# number of galaxies :  989666
# number of matter particles :  2190718
# number of galaxies randoms:  9900130
# number of matter randoms:  22136011
# setting up the class
# number of galaxies  989666
# number of galaxy randoms  9900130
# number of matter  2190718
# number of matter randoms  22136011
# correlating gg
# correlating g g
# time for correlating g g  1.4467136859893799
# correlating g rg
# time for correlating g rg  20.744988918304443
# correlating rg rg
# time for correlating rg rg  94.51400232315063
# r_gg [ 0.88922258  1.09448223  1.34712282  1.6590986   2.04084023  2.50873436
#   3.0874052   3.79687317  4.671644    5.74699839  7.06889524  8.69663573
#  10.69715626 13.15924354 16.18582324 19.90763632 24.48602642 30.11474584
#  37.03495768 45.54348244]
# xi_gg [2.70719027e+01 1.78032566e+01 1.23688896e+01 8.65581362e+00
#  6.23641664e+00 4.40290515e+00 3.22708890e+00 2.33619878e+00
# ...

# %%
# !python '/global/project/projectdirs/des/shivamp/cosmosis/y3kp-bias-model/3d_stats/process_measure_data/correlate_gg_gm_3d_funcs_mice_halos.py' --bin 2 --lm_min 12.0 --lm_max 12.5
# Out:
# 4.0.9
# nthreads are  64
# loading g
# loading m
# loading rg
# loading rm
# number of galaxies :  89219
# number of matter particles :  2212928
# number of galaxies randoms:  889667
# number of matter randoms:  21966969
# setting up the class
# number of galaxies  89219
# number of galaxy randoms  889667
# number of matter  2212928
# number of matter randoms  21966969
# correlating gg
# correlating g g
# time for correlating g g  0.06303906440734863
# correlating g rg
# time for correlating g rg  0.7216989994049072
# correlating rg rg
# time for correlating rg rg  1.42476224899292
# r_gg [ 0.88666563  1.09301614  1.34938847  1.66739699  2.04582091  2.50924438
#   3.08764723  3.79690088  4.67277984  5.74571608  7.0727182   8.70220438
#  10.71009098 13.16621096 16.19720775 19.91392662 24.49002328 30.11971551
#  37.04053045 45.54361897]
# xi_gg [9.36123658 8.83228898 5.90375318 4.1318896  2.80222603 2.36319865
#  1.57630022 1.09757922 0.92634702 0.63510956 0.484995   0.34142621
# ...

# %%
# !python '/global/project/projectdirs/des/shivamp/cosmosis/y3kp-bias-model/3d_stats/process_measure_data/correlate_gg_gm_3d_funcs_mice_halos.py' --bin 5 --lm_min 12.0 --lm_max 12.5 --do_mm 1 --do_gm 0 --do_gg 0
# Out:
# 4.0.9
# nthreads are  64
# loading g
# loading m
# loading rg
# loading rm
# number of galaxies :  247983
# number of matter particles :  6689040
# number of galaxies randoms:  2500768
# number of matter randoms:  67055735
# setting up the class
# number of galaxies  247983
# number of galaxy randoms  2500768
# number of matter  6689040
# number of matter randoms  67055735
# correlating mm
# correlatinm m m
# time for correlatinm m m  24.71020269393921
# correlatinm m rm
# time for correlatinm m rm  314.88532543182373
# correlatinm rm rm
# ^C

# %%
# !python '/global/project/projectdirs/des/shivamp/cosmosis/y3kp-bias-model/3d_stats/process_measure_data/correlate_gg_gm_3d_funcs_mice_halos.py' --bin 4 --lm_min 12.0 --lm_max 12.5 --do_mm 1 --do_gm 0 --do_gg 0
# Out:
# 4.0.9
# nthreads are  64
# loading g
# loading m
# loading rg
# loading rm
# number of galaxies :  201672
# number of matter particles :  5256321
# number of galaxies randoms:  2028412
# number of matter randoms:  52441774
# setting up the class
# number of galaxies  201672
# number of galaxy randoms  2028412
# number of matter  5256321
# number of matter randoms  52441774
# correlating mm
# correlatinm m m
# time for correlatinm m m  19.504639148712158
# correlatinm m rm
# time for correlatinm m rm  245.37075114250183
# correlatinm rm rm
# time for correlatinm rm rm  1541.9069867134094
# r_mm [ 0.88529446  1.09364038  1.34896269  1.6595904   2.04217916  2.51273971
#   3.09117687  3.80387417  4.68009058  5.75494063  7.07795459  8.70630264
#  10.70808909 13.16983748 16.19658537 19.9184906  24.4950122  30.12206068
#  37.0404744  45.54707721]
# xi_mm [9.53125115e+00 6.64550992e+00 4.20886794e+00 2.80595567e+00
#  1.91414490e+00 1.37881635e+00 1.00561332e+00 7.60215282e-01
# ...

# %%
# !python '/global/project/projectdirs/des/shivamp/cosmosis/y3kp-bias-model/3d_stats/process_measure_data/correlate_gg_gm_3d_funcs_mice_halos.py' --bin 3 --lm_min 12.0 --lm_max 12.5
# Out:
# 4.0.9
# nthreads are  64
# loading g
# loading m
# loading rg
# loading rm
# number of galaxies :  144018
# number of matter particles :  3668927
# number of galaxies randoms:  1469783
# number of matter randoms:  36996031
# setting up the class
# number of galaxies  144018
# number of galaxy randoms  1469783
# number of matter  3668927
# number of matter randoms  36996031
# correlating gg
# correlating g g
# time for correlating g g  0.10870933532714844
# correlating g rg
# time for correlating g rg  1.497361421585083
# correlating rg rg
# time for correlating rg rg  2.5017764568328857
# r_gg [ 0.88383649  1.09374252  1.34967003  1.65347488  2.04395756  2.51257103
#   3.08367423  3.80123393  4.67291564  5.74895771  7.07247235  8.70384689
#  10.70434086 13.16444135 16.19294985 19.9152683  24.49166347 30.11960151
#  37.04228576 45.55056906]
# xi_gg [10.09400496  8.69307149  5.69209345  4.41920325  2.85293156  2.27448083
# ...

# %%
# !python '/global/project/projectdirs/des/shivamp/cosmosis/y3kp-bias-model/3d_stats/process_measure_data/correlate_gg_gm_3d_funcs_mice_halos.py' --bin 3 --lm_min 12.0 --lm_max 12.5 --do_gg 0 --do_gm 1 --do_mm 0
# Out:
# 4.0.9
# nthreads are  45
# loading g
# loading m
# loading rg
# loading rm
# number of galaxies :  2382602
# number of matter particles :  3668927
# number of galaxies randoms:  24265183
# number of matter randoms:  36996031
# setting up the class
# number of galaxies  2382602
# number of galaxy randoms  24265183
# number of matter  3668927
# number of matter randoms  36996031
# correlating gm
# correlating g m
# time for correlating g m  12.033152103424072
# correlating g rm
# time for correlating g rm  143.39471817016602
# correlating m rg
# time for correlating m rg  115.8731050491333
# correlating rm rg
# time for correlating rm rg  835.3789668083191
# r_gm [ 0.88871705  1.09785015  1.35266609  1.66258743  2.04332387  2.5131898
#   3.09084332  3.80256221  4.67834804  5.7532231   7.07653642  8.70404625
#  10.70626777 13.16747835 16.19438894 19.91614548 24.4928165  30.12052548
#  37.03930075 45.54621688]
# xi_gm [5.21363392 4.72950323 3.72903904 2.95216316 2.27125287 1.73161667
# ...

# %%
# !python '/global/project/projectdirs/des/shivamp/cosmosis/y3kp-bias-model/3d_stats/process_measure_data/correlate_gg_gm_3d_funcs_mice_halos.py' --bin 5 --lm_min 12.5 --lm_max 13.0 --do_mm 0 --do_gm 1 --do_gg 1
# Out:
# 4.0.9
# nthreads are  45
# loading g
# loading m
# loading rg
# loading rm
# number of galaxies :  1249034
# number of matter particles :  6689040
# number of galaxies randoms:  12583241
# number of matter randoms:  67055735
# setting up the class
# number of galaxies  1249034
# number of galaxy randoms  12583241
# number of matter  6689040
# number of matter randoms  67055735
# correlating gg
# correlating g g
# time for correlating g g  1.7009625434875488
# correlating g rg
# time for correlating g rg  22.874472618103027
# correlating rg rg
# time for correlating rg rg  93.37499213218689
# r_gg [ 0.9021483   1.10382406  1.35125986  1.65982855  2.03976035  2.50880703
#   3.08616461  3.79750048  4.6728949   5.74663033  7.06887983  8.69654137
#  10.69828188 13.15882525 16.18617925 19.90734712 24.48446874 30.11321976
#  37.03281506 45.54064526]
# xi_gg [ 7.38403382 12.94661015 11.52986767  8.82729057  6.16167704  4.36029437
# ...

# %%
# !python '/global/project/projectdirs/des/shivamp/cosmosis/y3kp-bias-model/3d_stats/process_measure_data/correlate_gg_gm_3d_funcs_mice_halos.py' --bin 4 --lm_min 12.5 --lm_max 13.0 --do_mm 0 --do_gm 1 --do_gg 1
# Out:
# 4.0.9
# nthreads are  64
# loading g
# loading m
# loading rg
# loading rm
# number of galaxies :  1052932
# number of matter particles :  5256321
# number of galaxies randoms:  10560919
# number of matter randoms:  52441774
# setting up the class
# number of galaxies  1052932
# number of galaxy randoms  10560919
# number of matter  5256321
# number of matter randoms  52441774
# correlating gg
# correlating g g
# time for correlating g g  1.3836016654968262
# correlating g rg
# time for correlating g rg  19.072569847106934
# correlating rg rg
# time for correlating rg rg  73.81810188293457
# r_gg [ 0.90012804  1.10287958  1.35226861  1.65931758  2.04043806  2.50920894
#   3.08647847  3.79802803  4.67160458  5.74731424  7.0699259   8.69695824
#  10.69903078 13.15942638 16.18632049 19.90966785 24.48592202 30.11369342
#  37.03426385 45.54192809]
# xi_gg [ 7.13295933 11.68053758 10.65229081  8.0485361   5.68170791  4.04292834
# ...

# %%
# !python '/global/project/projectdirs/des/shivamp/cosmosis/y3kp-bias-model/3d_stats/process_measure_data/correlate_gg_gm_3d_funcs_mice_halos.py' --bin 3 --lm_min 12.5 --lm_max 13.0 --do_mm 0 --do_gm 1 --do_gg 1
# Out:
# ^C
# Traceback (most recent call last):
#   File "/usr/common/software/jupyter/19-09/lib/python3.7/sre_parse.py", line 236, in __next
#     char = self.decoded_string[index]
# IndexError: string index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/global/project/projectdirs/des/shivamp/cosmosis/y3kp-bias-model/3d_stats/process_measure_data/correlate_gg_gm_3d_funcs_mice_halos.py", line 2, in <module>
#     import numpy as np
#   File "/global/homes/s/spandey/.local/lib/python3.7/site-packages/numpy/__init__.py", line 187, in <module>
#     from .testing import Tester
#   File "/global/homes/s/spandey/.local/lib/python3.7/site-packages/numpy/testing/__init__.py", line 10, in <module>
#     from unittest import TestCase
#   File "/usr/common/software/jupyter/19-09/lib/python3.7/unittest/__init__.py", line 64, in <module>
#     from .main import TestProgram, main
# ...

# %%
# !python '/global/project/projectdirs/des/shivamp/cosmosis/y3kp-bias-model/3d_stats/process_measure_data/correlate_gg_gm_3d_funcs_mice_halos.py' --bin 5 --lm_min 13.0 --lm_max 13.5 --do_mm 0 --do_gm 1 --do_gg 1
# Out:
# ^C
# Traceback (most recent call last):
#   File "/global/project/projectdirs/des/shivamp/cosmosis/y3kp-bias-model/3d_stats/process_measure_data/correlate_gg_gm_3d_funcs_mice_halos.py", line 2, in <module>
#     import numpy as np
#   File "/global/homes/s/spandey/.local/lib/python3.7/site-packages/numpy/__init__.py", line 142, in <module>
#     from . import core
#   File "/global/homes/s/spandey/.local/lib/python3.7/site-packages/numpy/core/__init__.py", line 97, in <module>
#     from . import _add_newdocs
#   File "/global/homes/s/spandey/.local/lib/python3.7/site-packages/numpy/core/_add_newdocs.py", line 68, in <module>
#     """)
#   File "/global/homes/s/spandey/.local/lib/python3.7/site-packages/numpy/core/function_base.py", line 465, in add_newdoc
#     _add_docstring(new, doc.strip())
# KeyboardInterrupt

# %%
# !python '/global/project/projectdirs/des/shivamp/cosmosis/y3kp-bias-model/3d_stats/process_measure_data/correlate_gg_gm_3d_funcs_mice_halos.py' --bin 4 --lm_min 13.0 --lm_max 13.5 --do_mm 0 --do_gm 1 --do_gg 1
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/global/u1/s/spandey/myenv_new/lib/python2.7/site-packages/IPython/core/ultratb.py", line 1132, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/global/u1/s/spandey/myenv_new/lib/python2.7/site-packages/IPython/core/ultratb.py", line 313, in wrapped
#     return f(*args, **kwargs)
#   File "/global/u1/s/spandey/myenv_new/lib/python2.7/site-packages/IPython/core/ultratb.py", line 358, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/global/u1/s/spandey/myenv_new/lib/python2.7/inspect.py", line 1051, in getinnerframes
#     framelist.append((tb.tb_frame,) + getframeinfo(tb, context))
#   File "/global/u1/s/spandey/myenv_new/lib/python2.7/inspect.py", line 1015, in getframeinfo
# ...

# %%
# !python '/global/project/projectdirs/des/shivamp/cosmosis/y3kp-bias-model/3d_stats/process_measure_data/correlate_gg_gm_3d_funcs_mice_halos.py' --bin 5 --lm_min 13.5 --lm_max 14.0
# Out:
# nthreads are  64
# loading g
# loading m
# loading rg
# loading rm
# number of galaxies :  60792
# number of matter particles :  6689040
# number of galaxies randoms:  603968
# number of matter randoms:  66440448
# setting up the class
# number of galaxies  60792
# number of galaxy randoms  603968
# number of matter  6689040
# number of matter randoms  66440448
# correlating gg
# correlating g g
# time for correlating g g  0.304659366607666
# correlating g rg
# time for correlating g rg  1.3134956359863281
# correlating rg rg
# time for correlating rg rg  1.214120864868164
# r_gg [ 0.88712943  1.09089007  1.34145154  1.71767091  2.09517402  2.5405471
#   3.08675745  3.78696676  4.65864876  5.73083403  7.05230745  8.68763378
#  10.68059411 13.14288292 16.16774829 19.88134493 24.46346088 30.0994061
#  37.02948437 45.5302156 ]
# xi_gg [-1.83856898 -1.31931856 -0.83617004  0.48549543  7.09194906 14.96429014
#  15.89962396 12.58596513  7.91820292  5.56563977  3.85565904  2.56830139
# ...

# %%
# !python '/global/project/projectdirs/des/shivamp/cosmosis/y3kp-bias-model/3d_stats/process_measure_data/correlate_gg_gm_3d_funcs_mice_halos.py' --bin 2 --lm_min 14.0 --lm_max 14.5
# Out:
# nthreads are  64
# loading g
# loading m
# loading rg
# loading rm
# number of galaxies :  6191
# number of matter particles :  2212928
# number of galaxies randoms:  61914
# number of matter randoms:  22128532
# setting up the class
# number of galaxies  6191
# number of galaxy randoms  61914
# number of matter  2212928
# number of matter randoms  22128532
# correlating gg
# correlating g g
# time for correlating g g  0.08249831199645996
# correlating g rg
# time for correlating g rg  0.16977620124816895
# correlating rg rg
# time for correlating rg rg  0.0916597843170166
# r_gg [ 0.88712943  1.09089007  1.34145154  1.64956332  2.02844385  2.57459799
#   3.15972167  3.87128855  4.66468711  5.70544116  7.05875892  8.65808386
#  10.6490788  13.11421562 16.12521748 19.86179577 24.39863968 30.08825976
#  37.06449158 45.5890312 ]
# xi_gg [ 1.         -1.30784141 -0.66677435 -0.19055311 -1.23895062  2.66698973
#   8.52401463 15.68668126 15.11517598 10.26404429  6.85407461  4.990443
# ...
